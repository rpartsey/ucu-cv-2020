# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
images_dir = '../images'

test_image1_name = 'test1.png'
test_image2_name = 'test2.png'

test_image1_path = os.path.join(images_dir, test_image1_name)
test_image2_path = os.path.join(images_dir, test_image2_name)

# %%
# Helper functions: 

def show(image):
    plt.imshow(image, cmap='gray')
    plt.show()
    
    
def apply_kernel(image, kernel, stride=1, aggredation_type='mean'):
    pass

# %%
test_image1 = cv2.imread(test_image1_path, cv2.IMREAD_GRAYSCALE)

# %%
test_image1.shape
# Out:
# (128, 128)

# %%
show(test_image1)

# %%
test_image2 = cv2.imread(test_image2_path, cv2.IMREAD_GRAYSCALE)

# %%
test_image2.shape
# Out:
# (128, 128)

# %%
show(test_image2)

# %%
kernels_map = {
    '1': np.array([
        [0,  1, 0],
        [1, -4, 1],
        [0,  1, 0]
    ])
}

# %%
kernels_map['1']
# Out:
# array([[ 0,  1,  0],
#        [ 1, -4,  1],
#        [ 0,  1,  0]])
